# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Completer.use_jedi = False
import requests

# %%
headers = {
    'User-agent' : 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'X-Naver-Client-id': 'JXzTFSE9YGEQXVEKjOuk',
    'X-Naver-Client-Secret': 'Ms9xQJcloB'
}

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/blog.json?display=100&start=100&query=' + searchText
# print(targetSite)

response = requests.get(targetSite, headers=headers)
#print(type(response.text))
#print(response.text)
searchResult = response.json()
# print(type(searchResult))
# print(searchResult.keys())
#print(searchResult['items'])
items = searchResult['items']
for i in range(len(items)):
    print('{}'.format(items[i]), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 더조은
# {'title': '의정부주간보호, <b>더조은</b>주간보호센터,<b>더조은</b>주간보호~^^', 'link': 'https://blog.naver.com/more-good/223229766196', 'description': '<b>더조은</b> 어르신의 한주는 도토리 옮기기, 사과나무꾸미기 오색끈블럭활동, 바통체조~^^ <b>더조은</b>주간보호센터의 행복을 만들어 나갔습니다.~ 도토리 옮기기활동^^ 가을산에서 주워온 도토리를 수저로 옆어르신에거... ', 'bloggername': '의정부 더조은 주간보호센터', 'bloggerlink': 'blog.naver.com/more-good', 'postdate': '20231006'}
# ========================================================================================================================
# {'title': '충주경매 | 호암동 세영 <b>더조은</b> 아파트 35평 저렴한 법원 경매', 'link': 'https://blog.naver.com/chindole/223204805914', 'description': '안녕하세요 오늘 소개할 물건은 호암동 세영<b>더조은</b> 아파트 입니다. 감정가액 대비 1회 유찰되어 2회차 진행되고 있는데요 오는 10월 04일 청지지방법원 충주지원에서 2회차 매각이 진행될 예정입니다. 좀 더... ', 'bloggername': '최신 법원경매정보~☆★ / 30분전', 'bloggerlink': 'blog.naver.com/chindole', 'postdate': '20230907'}
# ========================================================================================================================
# {'title': '이너뷰티 저분자콜라겐 젤리, <b>더조은</b>팜 <b>더조은</b>뷰티업콜라겐', 'link': 'https://blog.naver.com/sinae105/222672213228', 'description': '<b>더조은</b>뷰티업콜라겐은 3세대 저분자 GPH 트리펩타이드 콜라겐으로 더 빠르고 효과적인 흡수가 가능해요. 저분자가 왜 중요하냐구요? 분자가 작을수록 흡수율이 높아지니까! <b>더조은</b> 뷰티업 콜라겐의 분자 크기는... ', 'bloggername': '욜로랄라 탄이와 누나', 'bloggerlink': 'blog.naver.com/sinae105', 'postdate': '20220314'}
# ========================================================================================================================
# {'title': '<b>더조은</b>팜 저분자어린콜라겐 먹는콜라겐 섭취 중', 'link': 'https://blog.naver.com/wls2295/222598940732', 'description': '저분자어린콜라겐 <b>더조은</b>팜에서 선택했어요 가루형보다 이렇게 덜 번거롭고 맛있는 젤리스틱으로 챙겨 먹을 수 있으니 1차적으로 간편해서 좋았고 맛도 맛있어서 간식 대신해서 먹을 정도의 간편함과 맛... ', 'bloggername': 'Audrey Kim', 'bloggerlink': 'blog.naver.com/wls2295', 'postdate': '20211219'}
# ========================================================================================================================
# {'title': '간단한 무뼈닭발 밀키트, <b>더조은</b> 믿은식품', 'link': 'https://blog.naver.com/ghkddbtjs12/223215951896', 'description': '제품입담 #<b>더조은</b>믿음식품 #무뼈닭발, 하루만에 신선 배송도착으로 저녁은 요녀석으로 확쩡이댯 요즘... 조리방법과 더 맛있게 먹는 방법 궁금한 사람들 나와나와~~ . . . . . 헤헤 1. 팬을 달구어 식용유를... ', 'bloggername': 'One day', 'bloggerlink': 'blog.naver.com/ghkddbtjs12', 'postdate': '20230919'}
# ========================================================================================================================
# {'title': '저분자어린콜라겐 <b>더조은</b>팜 젤리스틱 먹는콜라겐 섭취 중', 'link': 'https://blog.naver.com/wls2295/222650479987', 'description': '<b>더조은</b>팜 저분자 콜라겐 젤리스틱 #저분자피쉬콜라겐펩타이드 #저분자어류콜라겐펩타이드 #저분자어린콜라겐 #<b>더조은</b>팜 근거 자료 바탕으로 직접 가장 효율적인 방법으로 콜라겐을 약사들이 만들어 믿을 수... ', 'bloggername': 'Audrey Kim', 'bloggerlink': 'blog.naver.com/wls2295', 'postdate': '20220217'}
# ========================================================================================================================
# {'title': '2023년 <b>더조은</b>재활주간보호센터 3분기 운영위원회', 'link': 'https://blog.naver.com/thegood2023/223228675018', 'description': '개보수 현황 - 4분기 운영사업계획 - 시설환경 개선을 위한 개보수 심의 <b>더조은</b> 재활주간보호센터는 앞으로도 어르신들을 우선으로 생각하며 더 다양하고 질 높은 서비스를 제공하기 위해 노력하겠습니다!', 'bloggername': '더조은 재활주간보호센터', 'bloggerlink': 'blog.naver.com/thegood2023', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223167381277', 'description': '<b>더조은</b>재활노인복지센터 <b>더조은</b>재활노인복지센터 주간보호센터장 고영만 노인유치원 군산시 공단대로 226 삼원빌딩 2층 학교종 땡땡땡 컵을사용 신체운동 전통놀이 배워보기 063 463 7272 장마비가 잠깐... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230727'}
# ========================================================================================================================
# {'title': '울산찜질카페 힐링스토리 물보다<b>더조은</b>물 (근적외선으로... ', 'link': 'https://blog.naver.com/heaven9893/223177521192', 'description': '울산찜질카페 물보다<b>더조은</b>물 놀라워~~~ 프라이빗한 공간이라서 옷을 벗고 땀을 흘렸다 맨 살에 그대로 근적외선기계의 빛을 쬐면 더 좋다고 하셔서 처음에는 옷 입고 하다가 두번째부터는 제대로... ', 'bloggername': '끼부리는 한여사', 'bloggerlink': 'blog.naver.com/heaven9893', 'postdate': '20230807'}
# ========================================================================================================================
# {'title': '전주 에스테틱 1 : 1 맞춤 아로마테라피 <b>더조은</b>테라스파', 'link': 'https://blog.naver.com/oog1217/223222531105', 'description': '주말에 전주 에스테틱 <b>더조은</b>테라스파에서 아로마테라피 관리 받고 왔어요~ <b>더조은</b>테라스파는 전주 롯데백화점 뒤쪽 GS25 편의점 건물 코뎀빌딩 2층에 위치하고 있어요 주차장은 건물 지하주차장을 이용하면... ', 'bloggername': '먹은지의 여행 & 맛집 & 일상 솔직리뷰', 'bloggerlink': 'blog.naver.com/oog1217', 'postdate': '20230927'}
# ========================================================================================================================
# {'title': '전주 비만관리 개인 PT 추천 ‘<b>더조은</b>테라스파’', 'link': 'https://blog.naver.com/uri7515/223110927587', 'description': '전주 비만관리 개인 PT추천 ‘<b>더조은</b>테라스파’ 10:30 - 20:30 / 화요일 휴무 오늘은 전주 비만관리로 유명한 ‘<b>더조은</b>테라스파’를 방문했어요!! 위치는 전북 전주시 완산구 여울로 19 코뎀빌딩 2층 주차는 건물... ', 'bloggername': '율리의 기록집', 'bloggerlink': 'blog.naver.com/uri7515', 'postdate': '20230524'}
# ========================================================================================================================
# {'title': '광명역 GIDC 한식뷔페 <b>더조은</b> 한식뷔페 후기', 'link': 'https://blog.naver.com/arirangarira/223218292690', 'description': '광명역 GIDC 한식뷔페 <b>더조은</b> 한식뷔페 후기 롯데몰 코스트코 옆 건물 중앙대학교병원 아래 코스트코... 광명역 GIDC <b>더조은</b> 한식뷔페는 점심시간에는 손님들로 붐빕니다. 저녁시간은 낮보다는 한가한 편입니다.... ', 'bloggername': '감사연구소', 'bloggerlink': 'blog.naver.com/arirangarira', 'postdate': '20230922'}
# ========================================================================================================================
# {'title': '원단쇼핑몰 <b>더조은</b>원단 빈티지원단 예쁘다', 'link': 'https://blog.naver.com/hyunjin2ee/222540209253', 'description': '#원단쇼핑몰 #<b>더조은</b>원단 #빈티지원단 예쁘네요 ㅎㅎ 안녕하세요 잇님들 달래에요 :) 요즘 달래가 사진... 특히나 요즘 코로나로인해 가정에서 제품을 만드는 수요가 높아짐에 따라 원단이 더 많이 업뎃된다고 해... ', 'bloggername': '달래빛의 사는 이야기', 'bloggerlink': 'blog.naver.com/hyunjin2ee', 'postdate': '20211018'}
# ========================================================================================================================
# {'title': "조립, 임가공 전문업체 '<b>더조은</b> 컴퍼니'", 'link': 'https://blog.naver.com/thebetterassy/223216973594', 'description': "'<b>더조은</b> 컴퍼니' 오시는 길 인천광역시 부평구 부흥로 384, 3층 문의 : *** - **** - **** #제조 #조립 #검사 #포장 #임가공 #<b>더조은</b>컴퍼니 #아쎄이 #ASSY #어셈블리 #반조립 #부분조립 #단순조립 #부업... ", 'bloggername': '더조은 컴퍼니', 'bloggerlink': 'blog.naver.com/thebetterassy', 'postdate': '20230920'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 반복되는 규칙찾기 . 게이트볼', 'link': 'https://blog.naver.com/jangyudaycare/223210249864', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 아침.저녁 제법 선선한 바람이 부니 #가을 의 문턱에 한발짝 더 가까워 짐을 느껴집니다. #인지활동 으로 #반복되는규칙찾기 를 하였습니다. 순서대로... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230913'}
# ========================================================================================================================
# {'title': '세종시 미용실 <b>더조은</b> ~ 남자 파마', 'link': 'https://blog.naver.com/tjgus2738/221152331275', 'description': '도담동 <b>더조은</b> 미용실로 갈아? 탄 날이기도 합니다..; 그동안 앞머리를 올리는 파마를 쭉 해오다가..... 앞머리 기장을 좀 더 길러야 한다는군요~ 한 달 뒤에는 더 이뻐 질라나요? ㅎ 그전에 했던 앞머리... ', 'bloggername': '홍이하우스', 'bloggerlink': 'blog.naver.com/tjgus2738', 'postdate': '20171130'}
# ========================================================================================================================
# {'title': '하남시맛집 <b>더조은</b>국밥 미사강변점 후기', 'link': 'https://blog.naver.com/foodcoma_2pm/223211587595', 'description': '셀프로 더 떠서 드시면 됩니다 새우젓과 들깨가루는 테이블 옆에 있어서 취향껏 드시면 돼요! 특히 깍두기가 새콤달콤하니 맛있었어요 <b>더조은</b>국밥 미사강변점은 수육을 하루 두 번 직접 삶는다고 하셔요... ', 'bloggername': '오후2시식곤증', 'bloggerlink': 'blog.naver.com/foodcoma_2pm', 'postdate': '20230914'}
# ========================================================================================================================
# {'title': "울산 찜질카페 삼산찜질방 '물보다<b>더조은</b>물' 에서 노폐물 독소... ", 'link': 'https://blog.naver.com/dkdmd1234/223195680013', 'description': "오늘은 삼산동에 있는 찜질카페 '물보다 <b>더 조은</b>물'에 다녀왔는데요, 결론부터 말씀드리면 정말... 바로바로 이 항아리 안에는 '미네랄수'가 들어있답니다 미네랄수에 대해서는 밑에서 더 자세히 알려드릴게요!... ", 'bloggername': 'Yummy한 딸기 라이프', 'bloggerlink': 'blog.naver.com/dkdmd1234', 'postdate': '20230828'}
# ========================================================================================================================
# {'title': '망월동 맛집 <b>더조은</b>국밥 미사강변점', 'link': 'https://blog.naver.com/mamasofa/223214840788', 'description': '스카이폴리스 국밥 맛집 뜨근하고 푸짐한 점심 망월동 스카이폴리스에 있는 <b>더조은</b>국밥집 다녀왔어요.... 얼큰 국밥 정식 암뽕순대 + 전통순대 + 수육 얼큰국밥은 일반 국밥보다 더 매콤하고, 양념장도 많이... ', 'bloggername': '#카리온 #맛집리뷰 #카페리뷰 #요리레시피 :D', 'bloggerlink': 'blog.naver.com/mamasofa', 'postdate': '20230918'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223162808639', 'description': '<b>더조은</b>재활노인복지센터 <b>더조은</b>재활노인복지센터 주간보호센터장 고영만 노인유치원 군산시... 힘을 더 받고 나 자신도 더 열심히 가르치는 효과를 가져 온답니다 땀흘리며 보내는 시간들이 어르신들과 더... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230721'}
# ========================================================================================================================
# {'title': '송우리 <b>더조은</b> 고등전문학원오픈', 'link': 'https://blog.naver.com/gnb_songwoo/223197857870', 'description': '예쁘고 조용한 자습실이 생긴만큼 우리 친구들 더욱 정진할 수 있기를~ 공부할때 제일 이쁜 우리 친구들~~ 이제 고등전용관에서 열심히 공부하고 원하는 대학에 진할 할 수 있도록 <b>더조은</b> 학원이 응원하겠습니다.', 'bloggername': '더조은학원', 'bloggerlink': 'blog.naver.com/gnb_songwoo', 'postdate': '20230830'}
# ========================================================================================================================
# {'title': '울산<b>더조은</b>동물병원과 알아보는 강아지 눈병종류와 관리방법!', 'link': 'https://blog.naver.com/bsje2004/223229753323', 'description': '울산<b>더조은</b>동물병원과 알아보는 강아지 눈병종류와 관리방법! 강아지 눈에 특별한 문제가 없다면... 오늘은 <b>더조은</b>동물병원에서 강아지들에게 발생하는 대표적인 눈병 종류와 증상대해 알려드리도록... ', 'bloggername': '범서 더조은동물병원', 'bloggerlink': 'blog.naver.com/bsje2004', 'postdate': '20231006'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 과일가게 . 당신이최고야', 'link': 'https://blog.naver.com/jangyudaycare/223204765682', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 여름의 끝자락 시원한 바람이 솔솔 높고 맑은... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230907'}
# ========================================================================================================================
# {'title': '하남시맛집 <b>더조은</b>국밥집으로 점저하러 가보아요~^^', 'link': 'https://blog.naver.com/hyunj_jj/223215379492', 'description': '망월동맛집 <b>더조은</b>국밥집으로 건강한 식사하러 가기 요즘 공연이다 축제버스킹으로 바쁜 큰딸 이랑... 망월동맛집 <b>더조은</b>국밥집으로 고고씽~^^ 경기 하남시 미사강변한강로 135 스카이폴리스 B160 <b>더조은</b>국밥... ', 'bloggername': '쭈니의 하루', 'bloggerlink': 'blog.naver.com/hyunj_jj', 'postdate': '20230919'}
# ========================================================================================================================
# {'title': "[리뷰] 저분자어린콜라겐, '<b>더조은</b> 뷰티업 콜라겐'", 'link': 'https://blog.naver.com/h_jjianing/222594672905', 'description': '그리고 <b>더조은</b>팜은 약사들이 모여 만든 회사로 가장 효율적인 콜라겐원료, 함량, 분자량을 선택하여 만든 가성비 갑 젤리라고 하길래 더 열심히 먹으려고 해요 총 내용량은 30포로 한달치! 1일 1회 1포만... ', 'bloggername': '지아니의 일상다반사', 'bloggerlink': 'blog.naver.com/h_jjianing', 'postdate': '20211213'}
# ========================================================================================================================
# {'title': '저분자어린콜라겐 맛있기까지 하네♡ <b>더조은</b> 뷰티업 콜라겐!', 'link': 'https://blog.naver.com/wlstjs6234/222622607194', 'description': '저분자어린콜라겐은 <b>더조은</b> 뷰티업 콜라겐 입니다 ♡ GHP 콜라겐은 피부 콜라겐과 동일한 구조의... 특히 <b>더조은</b> 뷰티업 콜라겐은 약사들이 모여 만든 회사로 국산 콜라겐으로 약사들이 가장 효율적인 콜라겐... ', 'bloggername': '진선마을', 'bloggerlink': 'blog.naver.com/wlstjs6234', 'postdate': '20220115'}
# ========================================================================================================================
# {'title': '갈비 추천 양념등갈비 <b>더조은</b>고기', 'link': 'https://blog.naver.com/jjy790888/223133944086', 'description': '양념등갈비 <b>더조은</b>고기 에서 시켜서 먹어보세요 맛나게 양념이 잘 베어서 맛있게 먹기 좋아요 빛깔부터 너무 맛나게 보이죠 맛을 보면 더 좋아하실거에요 크기도 일정하고요 뼈에 살이 제대로 붙어 있어서 뜯어... ', 'bloggername': '케잌맘스토리', 'bloggerlink': 'blog.naver.com/jjy790888', 'postdate': '20230701'}
# ========================================================================================================================
# {'title': '파스타 <b>더조은</b> 케라틴 원샷 클리닉 20ml (문의)', 'link': 'https://blog.naver.com/hojumani/223176490665', 'description': '파스타 <b>더조은</b> 케라틴 원샷 클리닉 Pasta Thejoeun Keratin Oneshot Clinic 파스타 <b>더조은</b> 케라틴 원샷 클리닉 구매 문의 톡톡 주세요 파스타 <b>더조은</b> 케라틴 원샷 클리닉 20ml 파스타 <b>더조은</b> 케라틴 원샷... ', 'bloggername': '날마다헤어', 'bloggerlink': 'blog.naver.com/hojumani', 'postdate': '20230806'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 콤부차 레몬 마셔본 후기 (새콤달콤한 맛) 탄산 후식차', 'link': 'https://blog.naver.com/greensubini/222641163184', 'description': '주위에서 너도나도 마시길래 저도 맛이 궁금해서 구매해 봤습니다.ㅎㅎ 제가 선택한 것은 <b>더조은</b> 콤부차 레몬맛입니다. 복숭아맛이랑 고민하다가 상큼한 레몬맛부터 먹어보기로 햇어요. <b>더조은</b> 콤부차... ', 'bloggername': 'YOLO', 'bloggerlink': 'blog.naver.com/greensubini', 'postdate': '20220207'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 성폭력 예방 및 대응지침... ', 'link': 'https://blog.naver.com/ssjintermed/223205973436', 'description': '평택 <b>더조은</b> 요양원입니다. 벌써 한 주의 마지막인 금요일이 왔습니다 ! 이번 한 주도 고생이 많으셨고... 조금 더 관심있게 알아야 될 중요 할 정보들과 지식들을 강의에 잘 녹여서 설명해 주셔서 유익한... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230908'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223211070892', 'description': '<b>더조은</b>재활노인복지센터 <b>더조은</b>재활노인복지센터 주간보호센터장 고영만 노인유치원 군산시... 그런지 더 반갑구 보고싶구 그렇다 오늘도 신바람나게 접시를 치면서 노래하며 스트레스를 확 날려 버렸다... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230914'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 요양병원 장례식장에서 해양장으로 진행할 경우 해양장... ', 'link': 'https://blog.naver.com/daon8279/223188017903', 'description': '서울시 노원구 월계동에 위치한 <b>더조은</b> 요양병원 부속 장례식장에서 고인의 마지막을 잘 모시게... <b>더조은</b>요양병원에서 임종하셔서 바로 장례식장 안치실로 모시게 되었습니다. 장지상담을 하시면서 자연장에... ', 'bloggername': '다온상조 1800-8279', 'bloggerlink': 'blog.naver.com/daon8279', 'postdate': '20230819'}
# ========================================================================================================================
# {'title': '철갑상어 추출물 뷰티 프렌드 <b>더 조은</b> 마스크 팩 저녁애', 'link': 'https://blog.naver.com/ruby12170/223189267422', 'description': '<b>더 조은</b> 스킨 마스크... 저녁애에는 얼마나 많은 용액이 들어있는지... 제가 짜 보도록 할게요^^ 눈으로 확인하셨나요?? 아주 걸쭉한 용액이 듬뿍~ 얼굴에 바르고도 남아서... 목이나 팔, 다리도 다 발랐다능... ', 'bloggername': '참 착한 정연맘', 'bloggerlink': 'blog.naver.com/ruby12170', 'postdate': '20230821'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223154891078', 'description': '<b>더조은</b>재활노인복지센터 <b>더조은</b>재활노인복지센터 주간보호센터장 고영만 노인유치원 군산시... 활동하면서 더 건강하고 활기찬 삶을 즐길 수 있을 것입니다. 오늘도 어르신들의 건강과 행복을 듬뿍 드리고... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230713'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 스윙플러스 NS-001 골프 스윙연습기 후기', 'link': 'https://blog.naver.com/wls2295/221548356083', 'description': '골프 스윙연습기 <b>더조은</b> 스윙플러스 NS-001 아버지께서 집에서 골프 연습한다고 골프채로 바로 연습할... 길이는 더 짧아서 가정집에서 사용해도 길이감 덕분에 다른 물건 칠일과 마룻바닥 긁히는 위험은 없어... ', 'bloggername': 'Audrey Kim', 'bloggerlink': 'blog.naver.com/wls2295', 'postdate': '20190528'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 실버체조 (8월 마지막 주)', 'link': 'https://blog.naver.com/ssjintermed/223196732090', 'description': '평택 <b>더조은</b> 요양원입니다. 벌써 8월도 얼마 남지 않았습니다 ~ 무더위도 한 풀 꺾이는 듯 하는데요... 우리 <b>더조은</b> 요양원 어르신들~ 감사합니다 ~ 매주 하는 실버 체조이지만 항상 분위기는 뜨겁답니다... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230829'}
# ========================================================================================================================
# {'title': '안주/야식 메뉴로 추천하는 매콤한 무뼈 닭발 밀키트,<b>더조은</b>식품', 'link': 'https://blog.naver.com/sun_gram/223220252511', 'description': '<b>더조은</b> 홈페이지를 들어가보니 밀키트 전문점이여서 유통하는 사진도 직접보니 더 안심이였어요. 국내산으로 만든 매운 맛 닭발이여서 시킨 입장에서 믿고 먹었어요. 무뼈 닭발 선택할 때 소비기한 잘 확인을... ', 'bloggername': 'Charming_', 'bloggerlink': 'blog.naver.com/sun_gram', 'postdate': '20230924'}
# ========================================================================================================================
# {'title': '울산 남구 찜질방 물보다<b>더조은</b>물 삼산찜질방', 'link': 'https://blog.naver.com/dkdvkd789/223120547873', 'description': '물보다<b>더조은</b>물은 외곽에 있는 울산 찜질방이 아닌 도심에 있는 울산 남구 찜질방이에요 신발을... (물보다<b>더조은</b>물에서 흘린 땀은 끈적함이 없다고 해요) 저희는 카페 놀러 가기로 해서 화장도 다시해야... ', 'bloggername': '뽐디 ❁´◡`❁', 'bloggerlink': 'blog.naver.com/dkdvkd789', 'postdate': '20230605'}
# ========================================================================================================================
# {'title': "[수원 근막통증관리] 광교 마사지 '<b>더조은</b>김지윤바디케어' 후기", 'link': 'https://blog.naver.com/mh0024sa/223170982995', 'description': '받으러 <b>더조은</b>김지윤바디케어 다녀왔어요^^ 수원 근막통증관리 <b>더조은</b>김지윤바디케어 광교 마사지... ㅎㅎ 관리를 받는 동안 너무 달콤한 코코넛 향 덕분에 더 기분 좋게 통증관리를 받을 수 있었어요^^ 편하게... ', 'bloggername': '법률 기관 공고 전담 & 소소한 일상을 즐기기', 'bloggerlink': 'blog.naver.com/mh0024sa', 'postdate': '20230731'}
# ========================================================================================================================
# {'title': '울산남구찜질방 힐링스토리 물보다<b>더조은</b>물 깨끗한 찜질카페', 'link': 'https://blog.naver.com/dhkdrhks28/223202513534', 'description': '울산남구찜질방 힐링스토리 물보다<b>더조은</b>물 깨끗한 찜질카페 안녕하세요 츄윙클입니다^^ 엄마가... 엄마께서 더 맛있다고 하시더라고요 라면도 맛있고 구운계란도 탱글탱글 쫀득쫀득 너무 맛있더라고요... ', 'bloggername': '츄윙클의 반짝이는 뷰티', 'bloggerlink': 'blog.naver.com/dhkdrhks28', 'postdate': '20230904'}
# ========================================================================================================================
# {'title': '세종시 보람동미용실 <b>더조은</b>헤어 남성펌 만족스러운 후기', 'link': 'https://blog.naver.com/gaeul12/222510703686', 'description': '남편도 맘에 들어했지만 오랜만에 머리한 남편보니 제가 더 신이나네용 아 예뿌다 *_* 궁금해하실 <b>더조은</b>헤어 가격표입니다. 참고하세요~ <b>더조은</b>헤어 보람점 은우선생님이 스타일 도와주셨어요!! 명함과... ', 'bloggername': '어느날 문득 발견한 행복', 'bloggerlink': 'blog.naver.com/gaeul12', 'postdate': '20210919'}
# ========================================================================================================================
# {'title': '다이어트 간식 곤약젤리 : 2kcal <b>더 조은</b> 한끼 곤약젤리', 'link': 'https://blog.naver.com/1kg_otl/222816870815', 'description': '<b>더 조은</b> 한끼 곤약젤리 #다이어트곤약간식 #다이어트간식 이 제품 추천 이유는 ✔︎ 씹히는 내용물을 많이 때려 넣었어요 ✔︎ 2kcal 포만감 구웃!!!! 다른 곤약젤리 제품보다 유난히 씹히는게 많다고... ', 'bloggername': '아무리뷰', 'bloggerlink': 'blog.naver.com/1kg_otl', 'postdate': '20220718'}
# ========================================================================================================================
# {'title': '갈비 추천 <b>더조은</b>고기 돼지양념등갈비', 'link': 'https://blog.naver.com/zinizinly/223204651240', 'description': '<b>더조은</b>고기 1kg 돼지양념 등갈비 원재료 및 함량 / 원산지 : 등갈비(스페인) 60.24%, 전제수, 혼합간장(대두... 챙겨갔던 <b>더조은</b>고기 등갈비가 너무 맛있어서 오늘은 집에서 먹으려고 주문했어요. 9월임에도... ', 'bloggername': '겸이솜이', 'bloggerlink': 'blog.naver.com/zinizinly', 'postdate': '20230907'}
# ========================================================================================================================
# {'title': '<b>더조은</b>주간보호 송편만들기했어요~^^', 'link': 'https://blog.naver.com/thejoeun9980/223223060728', 'description': '음식장만, 시골갈준비, 애들용돈....등등등 저희 #<b>더조은</b>주간보호 에서도 추석맞이 송편만들기했어요!! 어르신들이 지금은 자녀분들한테 다 받으시지만 예전엔 방앗간가고 직접 송편만드셨잖아요.. 그 기억을... ', 'bloggername': 'The조은주간보호센터', 'bloggerlink': 'blog.naver.com/thejoeun9980', 'postdate': '20230927'}
# ========================================================================================================================
# {'title': '도담동 <b>더조은</b> 헤어살롱에서 두아이 낳고 첫 세팅펌 성공^^v', 'link': 'https://blog.naver.com/smile023/221173798639', 'description': "세종시미용실 어제보다 오늘 더 예쁘세요 '더' 이뻐지라고 '<b>더</b>' <b>조은</b> 헤어살롱 인가봐요 세종시미용실 <b>더조은</b> 헤어살롱 이름도 goooooooooooooooooood 세종시미용실 최고의 아이들을 위한 공간 아닐까요? 엄마라서... ", 'bloggername': '❤️해피별이맘❤️', 'bloggerlink': 'blog.naver.com/smile023', 'postdate': '20171229'}
# ========================================================================================================================
# {'title': '세종시미용실 <b>더조은</b>헤어살롱 다겸쌤 ~~', 'link': 'https://blog.naver.com/newsman24/221106451584', 'description': '함께 따라간 동생이 사진을 더 멋지게 잘 찍어 주었네요. 세종시 미용실 <b>더조은</b>헤어살롱 다겸쌤 정말 고마워요... 다음 달에 또 만나요 ^^ 저기 왼쪽에 보이는 방은 파우더룸인데. 안에 들어가서 셀카 찍으면 정말... ', 'bloggername': '한국영상마케팅협회', 'bloggerlink': 'blog.naver.com/newsman24', 'postdate': '20170927'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223207619507', 'description': '주시니 더 신나게 할 수 있다. 어르신들 아침 저녁으로 쌀쌀해졌어요 건강 잘 챙기시고 다음주에 환한얼굴로 다시 만나요 코리리코 예요 퍼즐마추기 두뇌운동 입니다 #쑤니커밍쑨봉사 #<b>더조은</b>재활노인복지... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230910'}
# ========================================================================================================================
# {'title': '골프스윙연습기, <b>더조은</b> 스윙플러스 골프스윙기 여성용으로 딱', 'link': 'https://blog.naver.com/mycutegod/222562470021', 'description': '<b>더조은</b> 스윙플러스는 실제 골프채보다 샤프트 길이가 짧고 헤드 무게가 더 무거운데 집이나 실외 어디서든 편하게 사용가능한 스윙연습기에요. 골프 스윙 자세, 궤도, 비거리, 헤드스피드, 방향성... ', 'bloggername': "럭키써니's Lifestyle", 'bloggerlink': 'blog.naver.com/mycutegod', 'postdate': '20211108'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 물감놀이', 'link': 'https://blog.naver.com/ssjintermed/223179167531', 'description': '평택 <b>더조은</b> 요양원입니다. 요즘 날씨가 매섭게 폭염이 진행이 되다가 오늘 부터 태풍이 북상을 한다고... 오늘은 평택 <b>더조은</b> 요양원에서 준비한 (여름 프로그램) 물감놀이를 준비 해 보았습니다 ! 모든... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230809'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 종이접기 . 순결한연꽃', 'link': 'https://blog.naver.com/jangyudaycare/223187055036', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 반가운 주말이 손짓하는 금요일 입니다. #인지활동... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230818'}
# ========================================================================================================================
# {'title': '보이차다이어트 솔직한 후기 - <b>더조은</b> 보이차스틱', 'link': 'https://blog.naver.com/a10000du/221224902060', 'description': '컄캬캬 이쁜라인찾기 <b>더조은</b> 보이차 1box 14개 요 한봉지당 1그램이 들어있다. 사실 나는 속으로 1그램이면 쥐똥만큼이자나? 했는데 일반 가루가 아닌 유효성분만을 추출해 농축분말로 만들어 더 진하고 더... ', 'bloggername': '만두로그', 'bloggerlink': 'blog.naver.com/a10000du', 'postdate': '20180309'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 전어구이 . 봉숭아꽃물들이기... ', 'link': 'https://blog.naver.com/jangyudaycare/223205980221', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센 입니다. 여름이 지나가고 가을에 접어들었음을 알리는 #가을... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230908'}
# ========================================================================================================================
# {'title': '대전 약국 인테리어~ <b>더조은</b> 약국 인테리어 공사', 'link': 'https://blog.naver.com/callajiny/222624850129', 'description': '포인트 등을 주어 과하지 않으면서 <b>더조은</b> 약국 만의 인테리어적인 요소를 가미하였습니다. 기다리시는... 이상 대전 약국 인테리어, 세종시 약국 인테리어~ <b>더조은</b>온누리 약국 인테리어 현장이었습니다.', 'bloggername': '데스파스', 'bloggerlink': 'blog.naver.com/callajiny', 'postdate': '20220118'}
# ========================================================================================================================
# {'title': '[<b>더조은</b>팜] 탱글탱글 저분자어린콜라겐, <b>더조은</b>뷰티업콜라겐', 'link': 'https://blog.naver.com/jtu0323/222482201202', 'description': '없어서 좋았어요^^ 촉촉하고 탱글탱글해서 차갑게 먹으면 더 맛있는 <b>더조은</b> 콜라겐! <b>더조은</b> 뷰티업 콜라겐 1포로 맛있고 탱글탱글하게 콜라겐 섭취하세요^^ 긴 글 읽어주셔서 감사합니다^^ 행복한 하루보내세요♡', 'bloggername': 'PonoDaily', 'bloggerlink': 'blog.naver.com/jtu0323', 'postdate': '20210824'}
# ========================================================================================================================
# {'title': '[<b>더조은</b>새마을금고] 연휴 주차장 무료개방 안내', 'link': 'https://blog.naver.com/kfcc1830/223217870937', 'description': '<b>더조은</b>새마을금고 여러분 안녕하세요! 벌써 선선한 가을 명절 추석이 다가오네요~^^ 명절에 주차... (공제문의) 더 다양하고 재미있는 이벤트가 계속 진행 될 예정이오니 많은 관심 부탁드립니다. 언제나... ', 'bloggername': '더조은새마을금고', 'bloggerlink': 'blog.naver.com/kfcc1830', 'postdate': '20230921'}
# ========================================================================================================================
# {'title': '<b>더조은</b>장례식장에서 서현추모공원까지 진행한 장례 후기', 'link': 'https://blog.naver.com/daonsangjo/223157111674', 'description': '이번 장례 후기는 서울 노원구 월계동에 위치한 <b>더조은</b> 장례식장입니다. <b>더조은</b> 요양병원 부속... 유가족분들과 상담한 내용으로 정확하게 물품을 제공하여 고인과의 이별에 슬프고 힘드신 유가족분들이 더... ', 'bloggername': '다온상조 후불제상조 1800-8279', 'bloggerlink': 'blog.naver.com/daonsangjo', 'postdate': '20230715'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 요양병원 장례식장에서 간소화 장례를 저렴하게 진행', 'link': 'https://blog.naver.com/daon8279/223182762230', 'description': '선한이웃병원 장례식장이었던 <b>더조은</b> 요양병원 장례식장에서 후불제상조 다온상조와 정성껏 장례를... 것이 더 큰 위로를 받으실 수 있습니다. 가족분들이 많지 않으시고 방문하실 조문객분들도 많지 않기에... ', 'bloggername': '다온상조 1800-8279', 'bloggerlink': 'blog.naver.com/daon8279', 'postdate': '20230813'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 모형지정색칠하기... ', 'link': 'https://blog.naver.com/jangyudaycare/223197675998', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 가을장마로 주말까지 날씨가 흐리고 비가... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889 감사합니다!... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230830'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 요리활동 - 카나페', 'link': 'https://blog.naver.com/jangyudaycare/223185971401', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 8월도 중순에 접어드니 불어오는 바람이 시원하게... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230817'}
# ========================================================================================================================
# {'title': '각화동<b>더조은</b>공간', 'link': 'https://blog.naver.com/kkok8999/223215171987', 'description': 'ㅡ정식,비빔밥,비빔국수,콩물국수)  <b>더조은</b>공간 안내 https://m.place.naver.com/restaurant/1327360138/location?selected=false  <b>더조은</b>공간ㅣ한식전문 플레이스 https://m.search.naver.com/p... ', 'bloggername': '우리동네상가', 'bloggerlink': 'blog.naver.com/kkok8999', 'postdate': '20230918'}
# ========================================================================================================================
# {'title': '마시자 <b>더조은</b> 보이차로 이쁜 라인 찾기!!', 'link': 'https://blog.naver.com/elfo1004/221260330522', 'description': '살짝 더 향이 향긋하게 느껴지구요 아침에 리안이 유치원 보내고 여유 있게 따뜻한 차로 한 잔, 커피도 좋은데 보이차 마시면서 커피 많이 줄인 것 같아요 보이차의 추출물들만 함유된 <b>더조은</b> 보이차 분말!... ', 'bloggername': '빛이 되겠습니다...', 'bloggerlink': 'blog.naver.com/elfo1004', 'postdate': '20180424'}
# ========================================================================================================================
# {'title': '동탄,오산 아이폰침수 세척 및 데이터복구 수리는 병점<b>더조은</b>폰!!', 'link': 'https://blog.naver.com/thejoeunpon/223186865785', 'description': '안녕하세요~ #화성아이폰수리전문점 <b>더조은</b>폰입니다!! 본격적인 휴가시즌.. 이제 코로나 거리두기... <b>더조은</b>폰에서는 확실한 수리전 점검 후 고객님의 니즈에 맞게 추천을 드리고 있습니다!! 그레서... ', 'bloggername': 'thejoeunpon님의블로그', 'bloggerlink': 'blog.naver.com/thejoeunpon', 'postdate': '20230818'}
# ========================================================================================================================
# {'title': '만들기 :: 향수만들기 재료 방산시장 <b>더조은</b>향기, THE조은향기', 'link': 'https://blog.naver.com/gals1113/221656222896', 'description': '한 #<b>더조은</b>향기 #the조은향기 를 갔당 토요일 낮이라 그런가 가게 안에 꽉 차버렸다ㅠㅠㅠ 역시 인기가... 구래서 더 잘 만들수 있어따 ㅎㅎㅎ 집에 가서 만들다가 모르는게 있으면 전화도 하라고 하셨다.... ', 'bloggername': '혬닝 블로그', 'bloggerlink': 'blog.naver.com/gals1113', 'postdate': '20190922'}
# ========================================================================================================================
# {'title': '광교 마사지 : 전신 바디관리 90분 힐링한 <b>더조은</b>김지윤바디케어', 'link': 'https://blog.naver.com/sunjlife/223191224458', 'description': '#광교마사지 #광교바디관리 <b>더조은</b>김지윤바디케어 2023.08. 당분간은 주말에 뒹굴거리지 못하고 열심히... 에스테틱 #<b>더조은</b>김지윤바디케어! 광교중흥S클래스 아파트앞 상가건물 어뮤즈스퀘어 지하 2층에... ', 'bloggername': '선율공간', 'bloggerlink': 'blog.naver.com/sunjlife', 'postdate': '20230824'}
# ========================================================================================================================
# {'title': '석계 <b>더조은</b> 요양병원 장례식장 천주교 장례!! 장지는 하늘문... ', 'link': 'https://blog.naver.com/daonsangjo/223172257465', 'description': '서울 노원구 월계동에 위치한 <b>더조은</b> 요양병원 장례식장입니다. 1호선과 6호선이 만나는 석계역 1번출구에서 불과 150m정도 떨어져 있어서 방문하시기에 교통 인프라가 좋습니다. <b>더조은</b> 요양병원 지하에 있지만... ', 'bloggername': '다온상조 후불제상조 1800-8279', 'bloggerlink': 'blog.naver.com/daonsangjo', 'postdate': '20230801'}
# ========================================================================================================================
# {'title': '[고양/파주]일산엑셀은 어디서? 일산<b>더조은</b>에서 시작!', 'link': 'https://blog.naver.com/tjoeunis/223045019713', 'description': '일산<b>더조은</b>입니다. 일교차가 큰 요즘, 따뜻한 봄이 성큼 다가온 기분이 드는데요! 모든 시작의 상징인... 엑셀과정을 소개합니다 :) 일산엑셀학원 일산<b>더조은</b>컴퓨터학원에서는 엑셀의 가장 기초... ', 'bloggername': '고양시국비지원 더조은컴퓨터학원 일산', 'bloggerlink': 'blog.naver.com/tjoeunis', 'postdate': '20230315'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223135417356', 'description': '<b>더조은</b>재활노인복지센터 <b>더조은</b>재활노인복지센터 주간보호센터장 고영만 노인유치원 군산시 공단대로 226 삼원빌딩 2층 소근육운동 : 별 색종이접기 레크리에이션 더크게 더힘차게 신체운동 063 463 7272... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230622'}
# ========================================================================================================================
# {'title': '저분자어류콜라겐펩타이드를 한포에! <b>더조은</b>팜 콜라겐젤리스틱', 'link': 'https://blog.naver.com/lxx_yj__/222570322196', 'description': '물도 더 많이 마셔주고 보습에 신경써주고 있어요 여기에 저분자어류콜라겐펩타이드가든 콜라겐도 함께 섭취하고 있답니다! 이왕 먹는거 맛있고 간편한게 꾸준히 챙겨먹기 좋을거 같아서 <b>더조은</b>팜에서 나온... ', 'bloggername': '소유의 나날', 'bloggerlink': 'blog.naver.com/lxx_yj__', 'postdate': '20211116'}
# ========================================================================================================================
# {'title': '자민경 로스제로 <b>더 조은</b> 안티헤어로스 샴푸 50g ▼ 3천원', 'link': 'https://uneenori.tistory.com/6530', 'description': 'ㅋㅋ 관심있으시면 체크하세여 자민경 로스제로 <b>더 조은</b> 안티헤어로스 샴푸 50g... [롯데홈쇼핑] [자민경](배송비체험: 9/16 12시30분 오픈) 로스제로 <b>더 조은</b> 안티헤어로... ', 'bloggername': '뷰티풀한노리', 'bloggerlink': 'https://uneenori.tistory.com/', 'postdate': '20230916'}
# ========================================================================================================================
# {'title': '위염 극복하기, <b>더조은</b> 양배추 브로콜리 즙', 'link': 'https://blog.naver.com/hyoeth/221310104975', 'description': '제가 <b>더조은</b> 사이트에서 보고 깜짝 놀란 건 심지어 이걸 한포로도 팔아요. 제가 살면서 이걸 한포로... 양배추 비리다고 못먹는 분들이 좀 있는데 <b>더 조은</b> 양배추 브로콜리는 맛이 진하지 않아서 비린맛을... ', 'bloggername': "당신의 'IF'는?", 'bloggerlink': 'blog.naver.com/hyoeth', 'postdate': '20180702'}
# ========================================================================================================================
# {'title': '울산찜질카페 물보다<b>더조은</b>물', 'link': 'https://blog.naver.com/wisdomsun06/223204363932', 'description': '더 좋더라구요!! 탈의실에서 환복후 한컷 찍어봅니다. ㅎㅎㅎ 안마기가 3대나 있네요! 안마기 좋아하는 엄마를 위해 ㅋㅋ 일단 안마코스부터~ 오! 제스파 안마기 네요^^ 오픈한지 얼마 안된 물보다<b>더조은</b>물... ', 'bloggername': '지혜하우스 매일매일 즐겁고 행복하게!!', 'bloggerlink': 'blog.naver.com/wisdomsun06', 'postdate': '20230906'}
# ========================================================================================================================
# {'title': "원단쇼핑몰 '<b>더조은</b>원단' 가리개커튼 등 인테리어 소품으로... ", 'link': 'https://blog.naver.com/min_ji73/222586269138', 'description': "그럴땐 식탁보를 이용하면 좋은데요 ୧( “̮ )୨✧ 미싱 사용이 가능하다면 굳이 비싼 식탁보를 사는 것보단 좀 더 저렴하게 원단을 구입해 식탁보로 만드는게 훨씬 이득이랍니다. 저는 원단쇼핑몰 '<b>더조은</b>원단... ", 'bloggername': '밈미네•ᴗ•♡✧*。', 'bloggerlink': 'blog.naver.com/min_ji73', 'postdate': '20211203'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 노래교실', 'link': 'https://blog.naver.com/ssjintermed/223176926142', 'description': '평택 <b>더조은</b> 요양원입니다. 여러분 폭염과 무더위에 많이 지치고 힘들거라고 예상이됩니다 ! 오늘... 평택 <b>더조은</b> 요양원이 응원 하겠습니다 ! 노래 교실 오늘도 어김없이 찾아온 노래교실 어르신들의... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230807'}
# ========================================================================================================================
# {'title': '저분자 콜라겐, <b>더조은</b> 뷰티업 콜라겐', 'link': 'https://blog.naver.com/kyongijoa/222269746488', 'description': '약사분들이 만들었다고 해서 믿음이 가는 <b>더조은</b> 뷰티업 콜라겐! 피부 생각하면 콜라겐을 안... 2% 이상 함유하는 GPH 저분자 피쉬 콜라겐을 1500mg 함유하고 있어 GPH가 없는 콜라겐과 비교했을때 더 빠르고... ', 'bloggername': 'Love for everyday', 'bloggerlink': 'blog.naver.com/kyongijoa', 'postdate': '20210309'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 광복절알기 . 부메랑불끄기', 'link': 'https://blog.naver.com/jangyudaycare/223185122700', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 가을이 점점 다가오는듯 아침,저녁이 제법... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230816'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 주간보호센터의 8월', 'link': 'https://blog.naver.com/kkal8304/223194186210', 'description': '때 <b>더조은</b> 어르신 한 분 한분에게 정다운 시간들로 하루하루를 아름답게 채워졌는지 반성하고... 시지주간보호 #경산주야간보호 #<b>더조은</b>주간보호센터 #<b>더조은</b>공동생활가정 #경산시장 #경산시 #어르신프로그램', 'bloggername': '더조은주간보호센터 & 공동생활가정', 'bloggerlink': 'blog.naver.com/kkal8304', 'postdate': '20230826'}
# ========================================================================================================================
# {'title': '골프스윙연습기 NS-002 <b>더조은</b> 스윙플러스 선택하여... ', 'link': 'https://blog.naver.com/wls2295/222493111110', 'description': '항상 <b>더조은</b>스윙프러스만 사용하셔서 동일 제품 다른 버전으로 더 추가했어요 이유는 사용하시면 아실 겁니다 골프 모르는 제가 봐도 재미있겠다 할 맛 나겠다 신기하다 새로운 제품인 거 같아요 무게감도... ', 'bloggername': 'Audrey Kim', 'bloggerlink': 'blog.naver.com/wls2295', 'postdate': '20210902'}
# ========================================================================================================================
# {'title': '<b>더조은</b>믿음식품 1인 무뼈닭발 밀키트 후기', 'link': 'https://blog.naver.com/travel_yuul/223220310027', 'description': '맛과 신선함에 한 번 더 놀랐던 <b>더조은</b>식품 무뼈닭발 야식 메뉴 고민이실 때나 집들이 음식, 손님 방문 음식, 안주, 캠핑장 등등 간편하게 이용할 수 있는 음식이 필요한 분들께 추천드립니다!! 본 포스팅은... ', 'bloggername': 'travel yuul', 'bloggerlink': 'blog.naver.com/travel_yuul', 'postdate': '20230924'}
# ========================================================================================================================
# {'title': '간단한 아침주스, <b>더조은</b> ABC주스', 'link': 'https://blog.naver.com/k13hhi/222118874496', 'description': '편한 <b>더조은</b> ABC주스 아무래도 건강프로그램이나 유튜브 통해 많이 알려지게되다보니 다양한 브랜드에서 출시되고 있는 것 같다. 이번에 먹어본 것은 <b>더조은</b>ABC주스이다. (ABC주스란! 사과(Appe), 비트(Beet)... ', 'bloggername': '블루베리라떼 34잔♥_♥', 'bloggerlink': 'blog.naver.com/k13hhi', 'postdate': '20201018'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 칠교놀이', 'link': 'https://blog.naver.com/ssjintermed/223173647679', 'description': '지금 까지 평택 <b>더조은</b>요양원의 칠교놀이 현장을 소개 해드렸습니다! 다음에도 더 좋은 프로그램을 찾아뵙겠습니다 ~ ▼▼▼▼▼▼▼▼▼▼▼▼아래 배너를 클릭 해주세요 !!... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230803'}
# ========================================================================================================================
# {'title': '콜라겐 젤리 저분자어린콜라겐 <b>더조은</b> 뷰티업 콜라겐', 'link': 'https://blog.naver.com/jsycuty/222483758993', 'description': '꼼꼼한 포장에 복숭아, 살구색 박스가 너무 예뻤어요!!!♡ 손글씨 같은 편지도 들어있어서 기분이 더 좋아지는 느낌!!&gt;_&lt; 콜라겐 젤리 저분자어린콜라겐 <b>더조은</b> 뷰티업 콜라겐 포장이 너무 예뻐서 이거 먹으면... ', 'bloggername': '* ✩‧₊Belle Diary * ✩', 'bloggerlink': 'blog.naver.com/jsycuty', 'postdate': '20210825'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 블록 &amp; 퍼즐놀이', 'link': 'https://blog.naver.com/ssjintermed/223186097681', 'description': '평택 <b>더조은</b> 요양원입니다. 요즘 들어 시간이 너무 빨리 가는 것 같아요 ! 벌써 여름의 끝을 달려가고... 좀 더 달라는 어르신, 모양을 어떻게 만들어 하는지 물어보는 어르신 등 프로그램에 엄청... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230817'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 질병건강안전교육... ', 'link': 'https://blog.naver.com/jangyudaycare/223198763153', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 어느덧 뜨거웠던 여름이 지나가고 시원한 바람이... 나만의 멋진 육각과반을 완성하시며 뿌듯한 시간을 보냈습니다^^ 주)<b>더조은</b>장유재활주간보호센터... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230831'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 물리치료', 'link': 'https://blog.naver.com/ssjintermed/223171647508', 'description': '평택요양원/서평택요양원/안중요양원/안중노인전문요양센터  안녕하세요~~ ♡〜٩( ˃́▿˂̀ )۶〜♡ 평택 <b>더조은</b> 요양원입니다. 오늘은 저희 <b>더조은</b>요양원의ㅣ 7월 4주차 물리치료 소식을 소개해 드리려고... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230801'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 8월 생신잔치', 'link': 'https://blog.naver.com/jangyudaycare/223177147443', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. #8월 생신을 맞으신 4분 어르신의 #생신잔치 를... 어르신들 생신 축하드리고 오래오래 건강하세요~♥ 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230807'}
# ========================================================================================================================
# {'title': '경남은행 BNK <b>더조은</b>자유적금 - 최고 연 4.55% 이자', 'link': 'https://blog.naver.com/2nd_it/223153824232', 'description': '제1금융권 은행인 경남은행에서 내놓은 최고 연 4.55% 이자를 주는 BNK<b>더조은</b>자유적금 상품 소식을 가져왔슴! ✅ 상품설명 BNK <b>더조은</b> 자유적금 상품 특징은 자유적립식 적금으로 매월 1만 원 이상부터... ', 'bloggername': '톨희의 머니머니해도', 'bloggerlink': 'blog.naver.com/2nd_it', 'postdate': '20230712'}
# ========================================================================================================================
# {'title': 'GPH콜라겐 <b>더조은</b>뷰티업 공구예약', 'link': 'https://blog.naver.com/siriniah/222248314636', 'description': '현직 약사가 만들었다면 일반인보다는 훨씬 더 깐깐하게 만들었겠다 싶었답니다. <b>더조은</b>뷰티업콜라겐은 석류농축액과 블루베리농축액과 프리바이오틱스인 프락토올리고당이 들어있어서 단맛이 있어서... ', 'bloggername': 'BORIS LOG', 'bloggerlink': 'blog.naver.com/siriniah', 'postdate': '20210219'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 실버체조', 'link': 'https://blog.naver.com/ssjintermed/223159335268', 'description': '평택 <b>더조은</b> 요양원입니다. 어제, 오늘 비가 많이 오는 바람에 홍수 피해가 크게 생기고 있습니다.... 어르신들이 잘 따라와 주시니 어르신들을 위해 강사님 더 열성적으로 해주시는데 너무 감사하게 생각하게... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230718'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 <b>더조은</b> 오락실', 'link': 'https://blog.naver.com/jangyudaycare/223180001757', 'description': '안녕하세요~ #<b>더조은</b>장유재활주간보호센터 입니다. 태풍 카눈의 영향으로 비바람이 많이쳐서 걱정했지만, 무사히 지나가서 다행입니다^^ 짜~잔!! #사회적응훈련 으로 <b>더조은</b> #오락실 을 준비하였습니다!!... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230810'}
# ========================================================================================================================
# {'title': '<b>더조은</b>콤부차 복숭아맛 레몬맛 다이어트음료로 추천!', 'link': 'https://blog.naver.com/yeonwoo_mom/223207054568', 'description': '모든 영양정보는 꼼꼼히보기 한포에 칼로리는 16칼로리입니다:) 더 더상큼한 레몬맛의, <b>더조은</b>콤부차 레몬맛 레몬은 접하기어려운 과일인데 콤부차로 만나니 새로웠어요ㅎㅎㅎ 복숭아맛과 마찬가지로... ', 'bloggername': "최공주's 맛집탐방♡", 'bloggerlink': 'blog.naver.com/yeonwoo_mom', 'postdate': '20230909'}
# ========================================================================================================================
# {'title': '광명역 GIDC 맛집 <b>더조은</b> 한식뷔페', 'link': 'https://blog.naver.com/minidodam/223077239006', 'description': '우와~우~ 예전에 <b>더조은</b> 한식뷔페가 아닙니다~ 경쟁점이 생겨서 더 좋아졌나 봅니다. ㅋㅋㅋ 먹는 직장인들은 기쁩니다. ㅋㅋㅋ 석식 메뉴도 10가지입니다. ㅎㅎㅎ 식권을 현금으로 하면 10+1 !!! 이니... ', 'bloggername': '도담디앤씨', 'bloggerlink': 'blog.naver.com/minidodam', 'postdate': '20230417'}
# ========================================================================================================================
# {'title': '적금추천 우리종합금융 <b>더조은</b>정기적금 만기 후기 +재가입 5.7%', 'link': 'https://blog.naver.com/lee_sten/223202818979', 'description': '작년 2022.09.05에 가입했던 우리종합금융 The조은정기적금이 오늘로 만기가 되었다!야호우 당시 내가... 모아놔야지 #적금추천 #적금만기 #우리종합금융 #우리종합금융<b>더조은</b> #우리종합금융the #적금이자... ', 'bloggername': '이슨생의 기록장', 'bloggerlink': 'blog.naver.com/lee_sten', 'postdate': '20230905'}
# ========================================================================================================================
# {'title': '평택 요양원 (평택 <b>더조은</b> 요양원) ㅣ 9월 달력 만들기', 'link': 'https://blog.naver.com/ssjintermed/223197705485', 'description': '평택 <b>더조은</b> 요양원입니다. 이제 여름도 끝 무렵이고 아침, 저녁으로 기온 차이가 많이납니다 ~ 이럴 때 일수록 더욱 더 건강에 유의 하시고 아침, 저녁 사이로 기온 차이가 많이 날 떄는 겉 옷같은 것을 챙겨... ', 'bloggername': '더조은요양원 우리함께평택점', 'bloggerlink': 'blog.naver.com/ssjintermed', 'postdate': '20230830'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 비말차단마스크 KF-AD 사용후기-', 'link': 'https://blog.naver.com/tlsduswjd88/222035868774', 'description': '<b>더조은</b> 비말차단마스크 KF-AD 사용후기- 11번가에서 십일절 타임특가로 떴던 <b>더조은</b> 비말차단마스크 한동안 마스크를 모은덕에 마스크 여유가 있었지만 가격이 저렴하게 나온것 같아서 고민하다가 결제했는데... ', 'bloggername': '기록이 정보가 되는 공간', 'bloggerlink': 'blog.naver.com/tlsduswjd88', 'postdate': '20200720'}
# ========================================================================================================================
# {'title': '<b>더조은</b> 주간보호센터 [9월을 행복으로 ....]', 'link': 'https://blog.naver.com/kkal8304/223201257293', 'description': '두꺼비학교 #주간보호센터 #아름다운동행 #중방동 #데이케어 #대구시지노인복지센터 #노인돌봄센터 #시지주간보호 #경산주야간보호 #<b>더조은</b>주간보호센터 #<b>더조은</b>공동생활가정 #경산시장 #경산시 #어르신프로그램', 'bloggername': '더조은주간보호센터 & 공동생활가정', 'bloggerlink': 'blog.naver.com/kkal8304', 'postdate': '20230903'}
# ========================================================================================================================
# {'title': "이너뷰티 저분자어린콜라겐 '<b>더조은</b>팜 먹는 콜라겐 젤리스틱... ", 'link': 'https://blog.naver.com/riko_5/222621788453', 'description': '영양제를 먹더라도 맛있으면 더 잘 챙겨 먹게 되는데 <b>더조은</b> 뷰티업 콜라겐 젤리스틱은 아주 만족스러운 맛! 평소 피부가 걱정이신 분들이라면 피부 고민을 덜어줄 <b>더조은</b>팜 먹는 콜라겐 젤리스틱 추천!!! 올해... ', 'bloggername': 'Loveriko', 'bloggerlink': 'blog.naver.com/riko_5', 'postdate': '20220114'}
# ========================================================================================================================
# {'title': '(주)<b>더조은</b>장유재활주간보호센터 오이마사지 . 모기를잡아라', 'link': 'https://blog.naver.com/jangyudaycare/223181011619', 'description': '안녕하세요~ <b>더조은</b>장유재활주간보호센터 입니다. 입추 . 말복이 지나니 살랑살랑 시원한 바람이 불어... 주)<b>더조은</b>장유재활주간보호센터 &quot;장기요양 등급 없으신분도 상담 도와드립니다&quot; 055) 333-2882 , 333-2889... ', 'bloggername': '(주)더조은장유재활주간보호센터', 'bloggerlink': 'blog.naver.com/jangyudaycare', 'postdate': '20230811'}
# ========================================================================================================================
# {'title': '저칼로리 디저트, 곤약젤리 후기 (<b>더조은</b>한끼 VS 돌DOLE)', 'link': 'https://blog.naver.com/yys9996/222309784042', 'description': '<b>더조은</b>한끼 곤약젤리 VS 돌 DOLE 곤약젤리 후기 남겨볼까해요^^ 저처럼 다욧트 하시는 분들 많으실거 같아 어느 맛이 더 괜찮은지 맛 후기 포스팅 남겨볼게요! <b>더조은</b> 한끼 곤약젤리 (와일드망고) 150ml / 2kcal... ', 'bloggername': '니나니뇨', 'bloggerlink': 'blog.naver.com/yys9996', 'postdate': '20210414'}
# ========================================================================================================================
# {'title': '<b>더조은</b>재활노인복지센터', 'link': 'https://blog.naver.com/napo114/223123276562', 'description': '<b>더조은</b>재활노인복지센터 <b>더조은</b>재활노인복지센터 주간보호센터장 고영만 노인유치원 군산시 공단대로 226 삼원빌딩 2층 두뇌개발 퍼즐맞추기 레크리에이션 접시를 가지고 신체운동 063 463 7272 오늘도... ', 'bloggername': '쑤니커밍쑨', 'bloggerlink': 'blog.naver.com/napo114', 'postdate': '20230608'}
# ========================================================================================================================
# {'title': '죽이야기 <b>더조은</b>죽 간편해서 먹기 너무 좋아요', 'link': 'https://blog.naver.com/vgomugomv/222258430452', 'description': '죽이야기 : <b>더조은</b>죽 죽이야기에서 집에서 편하게 쟁겨놓을 수 있는 <b>더조은</b>죽이 나왔어요~ 타업체에서도 이런 죽을 만나보았는데 이번에 죽이야기에서 <b>더조은</b>죽이 출시되었답니다 그것도 죽이야기에서 가장... ', 'bloggername': '박쏘쥬의 알딸딸한 이야기', 'bloggerlink': 'blog.naver.com/vgomugomv', 'postdate': '20210227'}
# ========================================================================================================================

# %% [markdown]
# 성인검색어 판별

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/adult.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
print(searchResult.keys())
adult = searchResult['adult']
print('{}(은)는 {} 검색어 입니다.'.format(searchText,'일반' if adult == '0' else '성인'))
# Out:
# 검색어 입력: 성인검색어
# dict_keys(['adult'])
# 성인검색어(은)는 일반 검색어 입니다.

# %% [markdown]
# 영화는 2023년 3월 부로 서비스 종료함 검색불가능함

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/movie.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
print(searchResult.keys())
items = searchResult['items']
for i in range(len(items)):
    print('{}'.format(items[i]), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 괴물
# dict_keys(['errorMessage', 'errorCode'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9652\3835017455.py in <module>
#       4 searchResult = response.json()
#       5 print(searchResult.keys())
# ----> 6 items = searchResult['items']
#       7 for i in range(len(items)):
#       8     print('{}'.format(items[i]), end='\n' + '=' * 120 + '\n')
#
# KeyError: 'items'

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/cafearticle.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
print(searchResult.keys())
items = searchResult['items']
for i in range(len(items)):
    print('{}'.format(items[i]), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 영화
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])
# {'title': '천박사 <b>영화</b>를 보고 왔어요.', 'link': 'http://cafe.naver.com/jinjululu/2365161', 'description': '낮시간에는 <b>영화</b>시작 30분 전인데도.. 예매한 사람이 하나도 없네요 ㅋㅋㅋ 동생아, 내가 너와 단둘이 보려고 빌렸어. 동생 화장실가서 혼자였음. 좀 무서운듯.. (<b>영화</b> 시작할 무렵 여성 두분 더 들어오셨어요 ㅜㅋㅋ) 널... ', 'cafename': '진주아지매', 'cafeurl': 'https://cafe.naver.com/jinjululu'}
# ========================================================================================================================
# {'title': '연휴동안 <b>영화</b>정복하기', 'link': 'http://cafe.naver.com/wooseongapt/495814', 'description': '명절에 갈곳도 없고 할일도없고해서 <b>영화</b>보기로 결정했어요 보고싶었는데 마침 씨네큐 시사회당첨으로 본<b>영화</b> 역시 강하늘 ㅎㅎ 연기짱입니다 재밋게 웃고 즐기고 왔어요 ㅎ 어이없이 웃고싶은분 보세요 흠~~~ 강동원 짱... ', 'cafename': '신도림 커뮤니티 [신커]', 'cafeurl': 'https://cafe.naver.com/wooseongapt'}
# ========================================================================================================================
# {'title': '일본 <b>영화</b> 티켓 온라인 구매 질문', 'link': 'http://cafe.naver.com/jpnstory/3328743', 'description': '일본 <b>영화</b> 티켓을 구입하려고 온라인 구매를 하려는데요. 미리 결제절차가 어떻게 되는지 궁금해서 회원가입하고 다른 <b>영화</b> 결제 전 단계까지 시도해봤는데 제가 이번에 보려는 <b>영화</b>가 무비티켓이 존재하는 <b>영화</b>입니다.... ', 'cafename': '네일동 : 일본여행카페', 'cafeurl': 'https://cafe.naver.com/jpnstory'}
# ========================================================================================================================
# {'title': '딸과 <b>영화</b> 데이트', 'link': 'http://cafe.naver.com/move79/4931900', 'description': '<b>영화</b> 시작 1시간 30분전에 미리 출발. 첨단 가는 길에 위치한 용전옛날손짜장 에서 자장면 1인1개 주문 후 촵촵. 응? 맛이 그닥인데 왜 낮부터 이리 사람이 많지?ㄷ 그래도 배고프니 호로록~~ <b>영화</b>는 팝콘과 함께... 원래 물만... ', 'cafename': '해돌 해피돌싱/올드싱글/이혼카페/재혼...', 'cafeurl': 'https://cafe.naver.com/move79'}
# ========================================================================================================================
# {'title': '<b>영화</b>보며 울어보신분 ?', 'link': 'http://cafe.naver.com/dlxogns01/141573', 'description': '사십대 후배가 추석연휴를 맞아 얼굴 보자고 해서 그러자 했는데 <b>영화</b>를 예매하겠다고 <b>영화</b>관으로 오래요. 버스 타고 전철 타고 차로 가면 십오분이면 갈거리를 사십분이 걸려 더듬 더듬 찾아가 본 <b>영화</b>는 보스톤 외국... ', 'cafename': '은퇴 후 50년 (은퇴자들의 모임)', 'cafeurl': 'https://cafe.naver.com/dlxogns01'}
# ========================================================================================================================
# {'title': '맛난거 먹고 <b>영화</b>봤어요 ㅎㅎ', 'link': 'http://cafe.naver.com/pajumom/4368315', 'description': '남편이 <b>영화</b>보다 먹지않겠나했는데 괜찮다고 안먹는다 했는데 ㅋㅋㅋ <b>영화</b>보다 중간에 먹고싶더라구용 ㅋㅋㅋ 결국 <b>영화</b> 다 보고 나와서 팝콘 샀어요 ㅋㅋㅋㅋ 애들도 오면 팝콘 줘야된다는 핑계로 ㅋㅋ 차에서 엄청... ', 'cafename': '파주맘 - 파주 대표카페 (운정,금촌,문...', 'cafeurl': 'https://cafe.naver.com/pajumom'}
# ========================================================================================================================
# {'title': '공포<b>영화</b> 좋아하시는 분', 'link': 'http://cafe.naver.com/ira111/748428', 'description': '공포<b>영화</b> 좋아하시는 분들 계실까요? ㅎㅎ 쌀쌀하니 공포<b>영화</b> 땡기네요ㅎ 저는 약간 컨저링이나 인시디어스 더넌 같은 엑소시즘 내용 들어간 <b>영화</b> 좋아해요. 이번에 더넌2 개봉했대서 보러가려구요!ㅋ 특이하다 생각하실... ', 'cafename': '미사강변도시 미사맘스클럽♡ 미사맘', 'cafeurl': 'https://cafe.naver.com/ira111'}
# ========================================================================================================================
# {'title': '<b>영화</b> &quot;1947 보스톤&quot;', 'link': 'http://cafe.naver.com/amateurmagician/30342', 'description': '연휴 마지막 날 보러 갔어요^^ 상영관 내부가 텅 비어 있어 괜히 보러 왔나 하는 생각이~ㅎ <b>영화</b>의 배경은 우리나라가 독립한 직후인 1947년입니다. 우리 경제가 어려운 시기였지요. 내용은 대충들 아시겠지요^^ <b>영화</b>... ', 'cafename': '아트프렌즈 Art Travel 미술관 갤러리...', 'cafeurl': 'https://cafe.naver.com/amateurmagician'}
# ========================================================================================================================
# {'title': '주말에 볼만한 <b>영화</b> 있을까요?', 'link': 'http://cafe.naver.com/endudfun/149293', 'description': '<b>영화</b>를 잘 안봤더니 어떤게 재미있는지 모르겠어요. 최근에 오펜하이머 봤는데 괜찮기는 했는데... 아주 재미있지는 않았어요. 스트레스도 많은데 생각 많은 <b>영화</b>보다는 재미있거나 웃긴<b>영화</b>가 보고 싶어요. 오래된... ', 'cafename': '분당 맹모', 'cafeurl': 'https://cafe.naver.com/endudfun'}
# ========================================================================================================================
# {'title': '30일 <b>영화</b>', 'link': 'http://cafe.naver.com/ilovegm1/2416092', 'description': '강하늘과 전소민의 30일 보고 왔어요^^ <b>영화</b> 줄거리를 하나도 모르고 가니 재미가 더하네요 왜 제목이 30일인가도 알게되었고 ㅋ 편하게 웃고 즐길 수 있는 <b>영화</b>인듯이요~~', 'cafename': '나눔카페 [구]광명맘&대디 -광명시,광...', 'cafeurl': 'https://cafe.naver.com/ilovegm1'}
# ========================================================================================================================

# %% [markdown]
# 오타 변환
# API를 호출하면 오타를 변환한 결과를 리턴하고 오타를 변환한 결과 . 오타가 없으면 빈 문자열을 반환합니다.

# %%
searchText = input('문장 입력: ').split()
result = []
print(searchText)
for text in searchText:
    targetSite = 'https://openapi.naver.com/v1/search/errata.json?query=' + text
    response = requests.get(targetSite, headers=headers)
    searchResult = response.json()
#    print(searchResult.keys())
    errata = searchResult['errata']
#    print(errata)
    # 오타갯수 확인
    if len(errata) == 0:
        print(text, end=' ')
        result.append(text)
    else:
        print(errata, end=' ')
        result.append(errata)
print()
print(' '.join(result))
# Out:
# 문장 입력: 아릉다운 이땅에 긍수강산에 단군하라버지가
# ['아릉다운', '이땅에', '긍수강산에', '단군하라버지가']
# 아름다운 이땅에 금수강산에 단군할아버지가
# 아름다운 이땅에 금수강산에 단군할아버지가
